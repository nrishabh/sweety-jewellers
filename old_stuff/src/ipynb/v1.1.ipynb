# %% [markdown]
# ## Dependencies:
# Pandas: `pip install pandas`<br>
# Pillow: `pip install pillow`<br>
# xlrd: `conda install -c conda-forge openpyxl`<br>
# tqdm: `pip install tqdm`<br>
#
# ***Only for development environment***<br>
# Jupyter Notebook: `conda install -c conda-forge notebook`<br>
# Jupyter Notebook Conda Connectors: `conda install -c conda-forge nb_conda_kernels`<br>

# %%
import os
import json
import time
import logging
import pandas as pd

from tqdm import tqdm
from datetime import datetime, timedelta
from PIL import Image, ImageFont, ImageDraw

# %% [markdown]
# ## Logging

# %%
if not os.path.exists(r"logs/"):
    logging.debug("No directory for logs found. Creating logs directory.")
    os.makedirs(r"logs/")

# Set up logging to file
LOGGING_DIR = r'logs/'
session_startTime = datetime.now()
local_tzname = (((session_startTime).astimezone()).tzinfo).tzname((session_startTime).astimezone())
logfile = session_startTime.strftime("Session_%d%b%y_%H%M%S.log")
# NOTE: File logging has been limited to INFO level
logging.basicConfig(format='%(name)s %(asctime)s: %(message)s', level=logging.INFO, datefmt='%d-%b-%y %H:%M:%S', filename=LOGGING_DIR+logfile)

# Set up logging for display stdout
console = logging.StreamHandler()
# NOTE: File logging has been not restricted
console.setLevel(logging.NOTSET)
formatter = logging.Formatter('%(asctime)s: %(message)s')
console.setFormatter(formatter)
logging.getLogger().addHandler(console)

# %% [markdown]
# ## Settings

# %%
SETTINGS_FILE = "settings.json"

with open(SETTINGS_FILE, mode='r', encoding='utf-8-sig') as f:
    settings = json.load(f)

# %%
def read_excel_file(file_details):
    
    # Read excel file
    df = pd.read_excel(file_details['xlsx_file'], engine='openpyxl', skiprows=file_details['skip_rows'])
    
    # Strip whitespace in str columns
    for col in df.columns:
        if df.dtypes[col]=='O':
            df[col].str.strip()
            df.fillna(value={col: ""})
    
    # Set primary key
    df.set_index(file_details['primary_key'], inplace=True)
    
    return df

# %%
item_catalog = read_excel_file(settings['item_catalog'])

# %%
purchase_orders = read_excel_file(settings['purchase_orders'])

# %%
# Sorting items according to purchase order dates
item_catalog['last_purchase_date'] = datetime(year=1990, month=1, day=1)
item_catalog['last_purchase'] = ''

for i in list(item_catalog.index):
    try:
        last_purchase_date = max(purchase_orders.at[i, 'Date'])
    except KeyError as e:
        item_catalog.at[i, 'last_purchase'] = 'Others'
        continue
    except TypeError as e:
        last_purchase_date = purchase_orders.at[i, 'Date']
    item_catalog.at[i, 'last_purchase_date'] = last_purchase_date
    if last_purchase_date>=(datetime.now()-timedelta(weeks=4)):
        item_catalog.at[i, 'last_purchase'] = 'This Month'
    elif last_purchase_date>=(datetime.now()-timedelta(weeks=8)):
        item_catalog.at[i, 'last_purchase'] = 'Last Month'
    else:
        item_catalog.at[i, 'last_purchase'] = 'Others'

# %%
# Reading JPG file paths
item_catalog['ip_file_path'] = ''
filepaths = os.listdir(settings['img_input_folder'])

for i in list(item_catalog.index):
    if ((i+".jpg") in filepaths):
        item_catalog.at[i, 'ip_file_path'] = settings['img_input_folder']+r"/"+i+".jpg"
    elif ((i+".jpeg") in filepaths):
        item_catalog.at[i, 'ip_file_path'] = settings['img_input_folder']+r"/"+i+".jpeg"
    else:
        logging.warning(f"Image not found for item {i}")
        continue
# Out:
# 2022-09-14 23:39:23,596: Image not found for item SJ-SBN-1001L
# 2022-09-14 23:39:23,602: Image not found for item SJ-SBN-1002L
# 2022-09-14 23:39:23,605: Image not found for item SJ-SBN-21L97
# 2022-09-14 23:39:23,608: Image not found for item SJ-SBN-22A31
# 2022-09-14 23:39:23,611: Image not found for item SJ-SBN-22A32
# 2022-09-14 23:39:23,613: Image not found for item SJ-SBN-414
# 2022-09-14 23:39:23,615: Image not found for item SJ-SBN-4174
# 2022-09-14 23:39:23,616: Image not found for item SJ-SBN-8509
# 2022-09-14 23:39:23,617: Image not found for item SJ-SBN-8510
# 2022-09-14 23:39:23,619: Image not found for item SJ-SBN-8526
# 2022-09-14 23:39:23,621: Image not found for item SJ-SBN-9155
# 2022-09-14 23:39:23,622: Image not found for item SJ-SBN-9156
# 2022-09-14 23:39:23,623: Image not found for item SJ-SBN-9191
# 2022-09-14 23:39:23,625: Image not found for item SJ-SSP-056
# 2022-09-14 23:39:23,629: Image not found for item SJ-SSP-105
# 2022-09-14 23:39:23,630: Image not found for item SJ-SSP-132L
# 2022-09-14 23:39:23,631: Image not found for item SJ-SSP-2144
# 2022-09-14 23:39:23,632: Image not found for item SJ-SSP-21K11
# 2022-09-14 23:39:23,633: Image not found for item SJ-SSP-21K12
# 2022-09-14 23:39:23,635: Image not found for item SJ-SSP-21K13
# 2022-09-14 23:39:23,637: Image not found for item SJ-SSP-21K35
# 2022-09-14 23:39:23,638: Image not found for item SJ-SSP-21K40
# 2022-09-14 23:39:23,639: Image not found for item SJ-SSP-21K41
# 2022-09-14 23:39:23,640: Image not found for item SJ-SSP-21K62
# 2022-09-14 23:39:23,641: Image not found for item SJ-SSP-21L04
# 2022-09-14 23:39:23,643: Image not found for item SJ-SSP-21L05
# 2022-09-14 23:39:23,644: Image not found for item SJ-SSP-21L07
# 2022-09-14 23:39:23,645: Image not found for item SJ-SSP-21L11
# 2022-09-14 23:39:23,646: Image not found for item SJ-SSP-2212
# 2022-09-14 23:39:23,647: Image not found for item SJ-SSP-2213
# 2022-09-14 23:39:23,648: Image not found for item SJ-SSP-22A01
# 2022-09-14 23:39:23,651: Image not found for item SJ-SSP-22A02
# 2022-09-14 23:39:23,652: Image not found for item SJ-SSP-22A03
# 2022-09-14 23:39:23,653: Image not found for item SJ-SSP-22A04
# 2022-09-14 23:39:23,654: Image not found for item SJ-SSP-22A18
# 2022-09-14 23:39:23,657: Image not found for item SJ-SSP-22A20
# 2022-09-14 23:39:23,658: Image not found for item SJ-SSP-22A23
# 2022-09-14 23:39:23,660: Image not found for item SJ-SSP-22C03
# 2022-09-14 23:39:23,663: Image not found for item SJ-SSP-22C06
# 2022-09-14 23:39:23,664: Image not found for item SJ-SSP-22F31
# 2022-09-14 23:39:23,666: Image not found for item SJ-SSP-22F33
# 2022-09-14 23:39:23,667: Image not found for item SJ-SSP-22F48
# 2022-09-14 23:39:23,668: Image not found for item SJ-SSP-22F49
# 2022-09-14 23:39:23,670: Image not found for item SJ-SSP-22F54
# 2022-09-14 23:39:23,671: Image not found for item SJ-SSP-22F55
# 2022-09-14 23:39:23,672: Image not found for item SJ-SSP-22F56
# 2022-09-14 23:39:23,673: Image not found for item SJ-SSP-22F57
# 2022-09-14 23:39:23,676: Image not found for item SJ-SSP-22F82
# 2022-09-14 23:39:23,677: Image not found for item SJ-SSP-22F83
# 2022-09-14 23:39:23,680: Image not found for item SJ-SSP-22F84
# 2022-09-14 23:39:23,682: Image not found for item SJ-SSP-22F85
# 2022-09-14 23:39:23,684: Image not found for item SJ-SSP-22F86
# 2022-09-14 23:39:23,685: Image not found for item SJ-SSP-22F87
# 2022-09-14 23:39:23,686: Image not found for item SJ-SSP-22F88
# 2022-09-14 23:39:23,687: Image not found for item SJ-SSP-22F89
# 2022-09-14 23:39:23,688: Image not found for item SJ-SSP-22G34
# 2022-09-14 23:39:23,690: Image not found for item SJ-SSP-22G35
# 2022-09-14 23:39:23,694: Image not found for item SJ-SSP-22G36
# 2022-09-14 23:39:23,695: Image not found for item SJ-SSP-22G37
# 2022-09-14 23:39:23,696: Image not found for item SJ-SSP-22G39
# 2022-09-14 23:39:23,697: Image not found for item SJ-SSP-22G40
# 2022-09-14 23:39:23,702: Image not found for item SJ-SSP-22G41
# 2022-09-14 23:39:23,704: Image not found for item SJ-SSP-22G42
# 2022-09-14 23:39:23,705: Image not found for item SJ-SSP-22G43
# 2022-09-14 23:39:23,706: Image not found for item SJ-SSP-22G44
# 2022-09-14 23:39:23,708: Image not found for item SJ-SSP-22G45
# 2022-09-14 23:39:23,709: Image not found for item SJ-SSP-22G46
# 2022-09-14 23:39:23,711: Image not found for item SJ-SSP-22G47
# 2022-09-14 23:39:23,712: Image not found for item SJ-SSP-22G48
# 2022-09-14 23:39:23,714: Image not found for item SJ-SSP-22G49
# 2022-09-14 23:39:23,716: Image not found for item SJ-SSP-22G50
# 2022-09-14 23:39:23,717: Image not found for item SJ-SSP-22G51
# 2022-09-14 23:39:23,718: Image not found for item SJ-SSP-22G53
# 2022-09-14 23:39:23,720: Image not found for item SJ-SSP-22G54
# 2022-09-14 23:39:23,721: Image not found for item SJ-SSP-22G55
# 2022-09-14 23:39:23,722: Image not found for item SJ-SSP-22G56
# 2022-09-14 23:39:23,723: Image not found for item SJ-SSP-22G57
# 2022-09-14 23:39:23,726: Image not found for item SJ-SSP-22G58
# 2022-09-14 23:39:23,728: Image not found for item SJ-SSP-22G59
# 2022-09-14 23:39:23,729: Image not found for item SJ-SSP-317
# 2022-09-14 23:39:23,731: Image not found for item SJ-SSP-332L
# 2022-09-14 23:39:23,732: Image not found for item SJ-SSP-4204
# 2022-09-14 23:39:23,734: Image not found for item SJ-SSP-590
# 2022-09-14 23:39:23,735: Image not found for item SJ-SSP-6207
# 2022-09-14 23:39:23,737: Image not found for item SJ-SSP-632L
# 2022-09-14 23:39:23,738: Image not found for item SJ-SSP-6824
# 2022-09-14 23:39:23,740: Image not found for item SJ-SSP-6953
# 2022-09-14 23:39:23,741: Image not found for item SJ-SSP-6954
# 2022-09-14 23:39:23,743: Image not found for item SJ-SSP-6956
# 2022-09-14 23:39:23,744: Image not found for item SJ-SSP-7014
# 2022-09-14 23:39:23,746: Image not found for item SJ-SSP-7058
# 2022-09-14 23:39:23,747: Image not found for item SJ-SSP-7059
# 2022-09-14 23:39:23,749: Image not found for item SJ-SSP-7060
# 2022-09-14 23:39:23,750: Image not found for item SJ-SSP-732L
# 2022-09-14 23:39:23,751: Image not found for item SJ-SSP-832L
# 2022-09-14 23:39:23,753: Image not found for item SJ-SSP-8517
# 2022-09-14 23:39:23,755: Image not found for item SJ-SSP-8544
# 2022-09-14 23:39:23,756: Image not found for item SJ-SSP-8805
# 2022-09-14 23:39:23,756: Image not found for item SJ-SSP-9012
# 2022-09-14 23:39:23,758: Image not found for item SJ-SSP-9013
# 2022-09-14 23:39:23,759: Image not found for item SJ-SSP-9070
# 2022-09-14 23:39:23,762: Image not found for item SJ-SSP-9087
# 2022-09-14 23:39:23,763: Image not found for item SJ-SSP-9110
# 2022-09-14 23:39:23,764: Image not found for item SJ-SSP-9133
# 2022-09-14 23:39:23,765: Image not found for item SJ-SSP-9139
# 2022-09-14 23:39:23,766: Image not found for item SJ-SSP-9140
# 2022-09-14 23:39:23,770: Image not found for item SJ-SSP-9141
# 2022-09-14 23:39:23,771: Image not found for item SJ-SSP-9186
# 2022-09-14 23:39:23,772: Image not found for item SJ-SSP-9215
# 2022-09-14 23:39:23,773: Image not found for item SJ-SSP-925I
# 2022-09-14 23:39:23,776: Image not found for item SJ-SHB-013
# 2022-09-14 23:39:23,779: Image not found for item SJ-SHB-014
# 2022-09-14 23:39:23,780: Image not found for item SJ-SHB-162
# 2022-09-14 23:39:23,781: Image not found for item SJ-SHB-182
# 2022-09-14 23:39:23,782: Image not found for item SJ-SHB-2007
# 2022-09-14 23:39:23,783: Image not found for item SJ-SHB-21K01
# 2022-09-14 23:39:23,784: Image not found for item SJ-SHB-21K03
# 2022-09-14 23:39:23,786: Image not found for item SJ-SHB-21K19
# 2022-09-14 23:39:23,787: Image not found for item SJ-SHB-21K45
# 2022-09-14 23:39:23,788: Image not found for item SJ-SHB-21K47
# 2022-09-14 23:39:23,789: Image not found for item SJ-SHB-21K51
# 2022-09-14 23:39:23,795: Image not found for item SJ-SHB-21L08
# 2022-09-14 23:39:23,796: Image not found for item SJ-SHB-21L16
# 2022-09-14 23:39:23,797: Image not found for item SJ-SHB-22E04
# 2022-09-14 23:39:23,799: Image not found for item SJ-SHB-22E05
# 2022-09-14 23:39:23,800: Image not found for item SJ-SHB-22E14
# 2022-09-14 23:39:23,801: Image not found for item SJ-SHB-22E15
# 2022-09-14 23:39:23,803: Image not found for item SJ-SHB-22F08
# 2022-09-14 23:39:23,805: Image not found for item SJ-SHB-22F09
# 2022-09-14 23:39:23,806: Image not found for item SJ-SHB-22F10
# 2022-09-14 23:39:23,808: Image not found for item SJ-SHB-22F11
# 2022-09-14 23:39:23,809: Image not found for item SJ-SHB-22F20
# 2022-09-14 23:39:23,810: Image not found for item SJ-SHB-22F21
# 2022-09-14 23:39:23,811: Image not found for item SJ-SHB-22F24
# 2022-09-14 23:39:23,813: Image not found for item SJ-SHB-22F25
# 2022-09-14 23:39:23,814: Image not found for item SJ-SHB-323
# 2022-09-14 23:39:23,815: Image not found for item SJ-SHB-324
# 2022-09-14 23:39:23,816: Image not found for item SJ-SHB-3630N
# 2022-09-14 23:39:23,817: Image not found for item SJ-SHB-3632N
# 2022-09-14 23:39:23,819: Image not found for item SJ-SHB-479
# 2022-09-14 23:39:23,820: Image not found for item SJ-SHB-6090
# 2022-09-14 23:39:23,821: Image not found for item SJ-SHB-6095
# 2022-09-14 23:39:23,822: Image not found for item SJ-SHB-6832
# 2022-09-14 23:39:23,823: Image not found for item SJ-SHB-6967
# 2022-09-14 23:39:23,825: Image not found for item SJ-SHB-7070
# 2022-09-14 23:39:23,828: Image not found for item SJ-SHB-8002
# 2022-09-14 23:39:23,832: Image not found for item SJ-SHB-8009
# 2022-09-14 23:39:23,833: Image not found for item SJ-SHB-909B
# 2022-09-14 23:39:23,835: Image not found for item SJ-SHB-9166
# 2022-09-14 23:39:23,836: Image not found for item SJ-SHB-918A
# 2022-09-14 23:39:23,838: Image not found for item SJ-SHB-9196
# 2022-09-14 23:39:23,839: Image not found for item SJ-SHB-9199
# 2022-09-14 23:39:23,840: Image not found for item SJ-SHB-9223
# 2022-09-14 23:39:23,842: Image not found for item SJ-SHB-926A
# 2022-09-14 23:39:23,844: Image not found for item SJ-SHB-9623
# 2022-09-14 23:39:23,846: Image not found for item TIS-SHB-2081
# 2022-09-14 23:39:23,847: Image not found for item SJ-SCH-22Z26
# 2022-09-14 23:39:23,848: Image not found for item SJ-JCH-7020
# 2022-09-14 23:39:23,850: Image not found for item SJ-JCH-7021
# 2022-09-14 23:39:23,851: Image not found for item SJ-SCH-1003L
# 2022-09-14 23:39:23,853: Image not found for item SJ-SCH-101R
# 2022-09-14 23:39:23,854: Image not found for item SJ-SCH-1067
# 2022-09-14 23:39:23,855: Image not found for item SJ-SCH-205
# 2022-09-14 23:39:23,857: Image not found for item SJ-SCH-2153
# 2022-09-14 23:39:23,858: Image not found for item SJ-SCH-21K63
# 2022-09-14 23:39:23,859: Image not found for item SJ-SCH-21K64
# 2022-09-14 23:39:23,860: Image not found for item SJ-SCH-21K65
# 2022-09-14 23:39:23,863: Image not found for item SJ-SCH-21K66
# 2022-09-14 23:39:23,864: Image not found for item SJ-SCH-21K67
# 2022-09-14 23:39:23,866: Image not found for item SJ-SCH-21K68
# 2022-09-14 23:39:23,868: Image not found for item SJ-SCH-21K84
# 2022-09-14 23:39:23,869: Image not found for item SJ-SCH-21L105
# 2022-09-14 23:39:23,871: Image not found for item SJ-SCH-21L13
# 2022-09-14 23:39:23,873: Image not found for item SJ-SCH-21L22
# 2022-09-14 23:39:23,874: Image not found for item SJ-SCH-21L28
# 2022-09-14 23:39:23,875: Image not found for item SJ-SCH-21L34
# 2022-09-14 23:39:23,877: Image not found for item SJ-SCH-21L35
# 2022-09-14 23:39:23,878: Image not found for item SJ-SCH-21L36
# 2022-09-14 23:39:23,880: Image not found for item SJ-SCH-21L38
# 2022-09-14 23:39:23,882: Image not found for item SJ-SCH-21L39
# 2022-09-14 23:39:23,883: Image not found for item SJ-SCH-21L33
# 2022-09-14 23:39:23,885: Image not found for item SJ-SCH-21L31
# 2022-09-14 23:39:23,887: Image not found for item SJ-SCH-21L40
# 2022-09-14 23:39:23,889: Image not found for item SJ-SCH-21L87
# 2022-09-14 23:39:23,890: Image not found for item SJ-SCH-22A05
# 2022-09-14 23:39:23,892: Image not found for item SJ-SCH-22C04
# 2022-09-14 23:39:23,894: Image not found for item SJ-SCH-22F50
# 2022-09-14 23:39:23,895: Image not found for item SJ-SCH-22G28
# 2022-09-14 23:39:23,897: Image not found for item SJ-SCH-22G29
# 2022-09-14 23:39:23,898: Image not found for item SJ-SCH-22G30
# 2022-09-14 23:39:23,899: Image not found for item SJ-SCH-254
# 2022-09-14 23:39:23,900: Image not found for item SJ-SCH-295
# 2022-09-14 23:39:23,902: Image not found for item SJ-SCH-3081
# 2022-09-14 23:39:23,903: Image not found for item SJ-SCH-3563A
# 2022-09-14 23:39:23,904: Image not found for item SJ-SCH-394
# 2022-09-14 23:39:23,906: Image not found for item SJ-SCH-4019
# 2022-09-14 23:39:23,907: Image not found for item SJ-SCH-4175
# 2022-09-14 23:39:23,908: Image not found for item SJ-SCH-421
# 2022-09-14 23:39:23,909: Image not found for item SJ-SCH-6002
# 2022-09-14 23:39:23,911: Image not found for item SJ-SCH-6003
# 2022-09-14 23:39:23,912: Image not found for item SJ-SCH-6004
# 2022-09-14 23:39:23,914: Image not found for item SJ-SCH-6005
# 2022-09-14 23:39:23,915: Image not found for item SJ-SCH-6006
# 2022-09-14 23:39:23,916: Image not found for item SJ-SCH-6008
# 2022-09-14 23:39:23,917: Image not found for item SJ-SCH-6010
# 2022-09-14 23:39:23,918: Image not found for item SJ-SCH-6018
# 2022-09-14 23:39:23,920: Image not found for item SJ-SCH-6030
# 2022-09-14 23:39:23,923: Image not found for item SJ-SCH-6049
# 2022-09-14 23:39:23,924: Image not found for item SJ-SCH-6167
# 2022-09-14 23:39:23,925: Image not found for item SJ-SCH-6713
# 2022-09-14 23:39:23,926: Image not found for item SJ-SCH-6802
# 2022-09-14 23:39:23,929: Image not found for item SJ-SCH-6884
# 2022-09-14 23:39:23,931: Image not found for item SJ-SCH-6892
# 2022-09-14 23:39:23,933: Image not found for item SJ-SCH-6894
# 2022-09-14 23:39:23,934: Image not found for item SJ-SCH-6999
# 2022-09-14 23:39:23,936: Image not found for item SJ-SCH-8001
# 2022-09-14 23:39:23,938: Image not found for item SJ-SCH-8003
# 2022-09-14 23:39:23,939: Image not found for item SJ-SCH-8005
# 2022-09-14 23:39:23,940: Image not found for item SJ-SCH-8007
# 2022-09-14 23:39:23,942: Image not found for item SJ-SCH-8013
# 2022-09-14 23:39:23,943: Image not found for item SJ-SCH-8015
# 2022-09-14 23:39:23,945: Image not found for item SJ-SCH-8523
# 2022-09-14 23:39:23,947: Image not found for item SJ-SCH-8524
# 2022-09-14 23:39:23,949: Image not found for item SJ-SCH-9019
# 2022-09-14 23:39:23,950: Image not found for item SJ-SCH-9054
# 2022-09-14 23:39:23,952: Image not found for item SJ-SCH-9094
# 2022-09-14 23:39:23,953: Image not found for item SJ-SCH-9095
# 2022-09-14 23:39:23,955: Image not found for item SJ-SCH-9096
# 2022-09-14 23:39:23,956: Image not found for item SJ-SCH-9097
# 2022-09-14 23:39:23,957: Image not found for item SJ-SCH-9098
# 2022-09-14 23:39:23,958: Image not found for item SJ-SCH-9100
# 2022-09-14 23:39:23,961: Image not found for item SJ-SCH-9151
# 2022-09-14 23:39:23,963: Image not found for item SJ-SCH-9157
# 2022-09-14 23:39:23,964: Image not found for item SJ-SCH-9205
# 2022-09-14 23:39:23,965: Image not found for item SJ-SCH-9206
# 2022-09-14 23:39:23,967: Image not found for item SJ-SCH-9207
# 2022-09-14 23:39:23,968: Image not found for item SJ-SCH-9208
# 2022-09-14 23:39:23,969: Image not found for item SJ-SCH-9209
# 2022-09-14 23:39:23,971: Image not found for item SJ-SCH-9211
# 2022-09-14 23:39:23,973: Image not found for item SJ-SCH-9211N
# 2022-09-14 23:39:23,974: Image not found for item SJ-SCH-9212
# 2022-09-14 23:39:23,976: Image not found for item SJ-SCH-9212N
# 2022-09-14 23:39:23,977: Image not found for item SJ-SCH-9213
# 2022-09-14 23:39:23,979: Image not found for item SJ-SCH-9311
# 2022-09-14 23:39:23,981: Image not found for item SJ-SCH-9312
# 2022-09-14 23:39:23,982: Image not found for item SJ-SCH-9313
# 2022-09-14 23:39:23,984: Image not found for item SJ-SCH-9314
# 2022-09-14 23:39:23,985: Image not found for item SJ-SCH-9316
# 2022-09-14 23:39:23,986: Image not found for item SJ-SCH-9328
# 2022-09-14 23:39:23,987: Image not found for item SJ-SCH-9329
# 2022-09-14 23:39:23,989: Image not found for item SJ-SCH-9341
# 2022-09-14 23:39:23,990: Image not found for item SJ-SCH-9342
# 2022-09-14 23:39:23,992: Image not found for item SJ-SSP-22F03
# 2022-09-14 23:39:23,993: Image not found for item SJ-SSP-22F04
# 2022-09-14 23:39:23,994: Image not found for item SJ-SSP-22F05
# 2022-09-14 23:39:23,996: Image not found for item SJ-SHP-3133
# 2022-09-14 23:39:23,997: Image not found for item SJ-SHP-579
# 2022-09-14 23:39:23,999: Image not found for item SJ-SHP-623A
# 2022-09-14 23:39:24,000: Image not found for item SJ-SJP-139
# 2022-09-14 23:39:24,001: Image not found for item SJ-SJP-141
# 2022-09-14 23:39:24,003: Image not found for item SJ-SJP-22A19
# 2022-09-14 23:39:24,004: Image not found for item SJ-SJP-22E13
# 2022-09-14 23:39:24,006: Image not found for item SJ-SJP-9326
# 2022-09-14 23:39:24,008: Image not found for item SJ-SJP-FANCY
# 2022-09-14 23:39:24,009: Image not found for item SJ-SRB-098
# 2022-09-14 23:39:24,011: Image not found for item SJ-SRB-099
# 2022-09-14 23:39:24,012: Image not found for item SJ-SRB-101
# 2022-09-14 23:39:24,014: Image not found for item SJ-SRB-102
# 2022-09-14 23:39:24,017: Image not found for item SJ-SRB-107N
# 2022-09-14 23:39:24,018: Image not found for item SJ-SRB-106N
# 2022-09-14 23:39:24,019: Image not found for item SJ-SRB-105N
# 2022-09-14 23:39:24,020: Image not found for item SJ-SRB-104N
# 2022-09-14 23:39:24,021: Image not found for item SJ-SRB-107
# 2022-09-14 23:39:24,023: Image not found for item SJ-SRB-108
# 2022-09-14 23:39:24,024: Image not found for item SJ-SRB-1101L
# 2022-09-14 23:39:24,025: Image not found for item SJ-SRB-1102L
# 2022-09-14 23:39:24,026: Image not found for item SJ-SRB-1103L
# 2022-09-14 23:39:24,028: Image not found for item SJ-SRB-1115
# 2022-09-14 23:39:24,029: Image not found for item SJ-SRB-1245
# 2022-09-14 23:39:24,032: Image not found for item SJ-SRB-215
# 2022-09-14 23:39:24,033: Image not found for item SJ-SRB-21K61
# 2022-09-14 23:39:24,035: Image not found for item SJ-SRB-21L01
# 2022-09-14 23:39:24,036: Image not found for item SJ-SRB-21L02
# 2022-09-14 23:39:24,038: Image not found for item SJ-SRB-21L45
# 2022-09-14 23:39:24,040: Image not found for item SJ-SRB-21L47
# 2022-09-14 23:39:24,041: Image not found for item SJ-SRB-21L48
# 2022-09-14 23:39:24,042: Image not found for item SJ-SRB-21L49
# 2022-09-14 23:39:24,044: Image not found for item SJ-SRB-22C13
# 2022-09-14 23:39:24,046: Image not found for item SJ-SRB-22E01
# 2022-09-14 23:39:24,047: Image not found for item SJ-SRB-22E02
# 2022-09-14 23:39:24,048: Image not found for item SJ-SRB-22E03
# 2022-09-14 23:39:24,049: Image not found for item SJ-SRB-22E16B
# 2022-09-14 23:39:24,051: Image not found for item SJ-SRB-22E18
# 2022-09-14 23:39:24,053: Image not found for item SJ-SRB-22F106
# 2022-09-14 23:39:24,054: Image not found for item SJ-SRB-22F12
# 2022-09-14 23:39:24,055: Image not found for item SJ-SRB-22F13
# 2022-09-14 23:39:24,057: Image not found for item SJ-SRB-22F14
# 2022-09-14 23:39:24,058: Image not found for item SJ-SRB-22F15
# 2022-09-14 23:39:24,059: Image not found for item SJ-SRB-22F16
# 2022-09-14 23:39:24,061: Image not found for item SJ-SRB-22F17
# 2022-09-14 23:39:24,062: Image not found for item SJ-SRB-22F18
# 2022-09-14 23:39:24,063: Image not found for item SJ-SRB-22F19
# 2022-09-14 23:39:24,064: Image not found for item SJ-SRB-22F22
# 2022-09-14 23:39:24,065: Image not found for item SJ-SRB-22F23
# 2022-09-14 23:39:24,067: Image not found for item SJ-SRB-22F34
# 2022-09-14 23:39:24,068: Image not found for item SJ-SRB-22F41
# 2022-09-14 23:39:24,069: Image not found for item SJ-SRB-22F42
# 2022-09-14 23:39:24,070: Image not found for item SJ-SRB-22F43
# 2022-09-14 23:39:24,071: Image not found for item SJ-SRB-22F43B
# 2022-09-14 23:39:24,072: Image not found for item SJ-SRB-22F44
# 2022-09-14 23:39:24,073: Image not found for item SJ-SRB-22F44B
# 2022-09-14 23:39:24,075: Image not found for item SJ-SRB-22F45
# 2022-09-14 23:39:24,076: Image not found for item SJ-SRB-22F46
# 2022-09-14 23:39:24,078: Image not found for item SJ-SRB-22F47
# 2022-09-14 23:39:24,079: Image not found for item SJ-SRB-22F52
# 2022-09-14 23:39:24,081: Image not found for item SJ-SRB-22F64
# 2022-09-14 23:39:24,082: Image not found for item SJ-SRB-22F65
# 2022-09-14 23:39:24,083: Image not found for item SJ-SRB-22F66
# 2022-09-14 23:39:24,084: Image not found for item SJ-SRB-22F67
# 2022-09-14 23:39:24,087: Image not found for item SJ-SRB-22F68
# 2022-09-14 23:39:24,089: Image not found for item SJ-SRB-22F69
# 2022-09-14 23:39:24,090: Image not found for item SJ-SRB-22F70
# 2022-09-14 23:39:24,092: Image not found for item SJ-SRB-22F71
# 2022-09-14 23:39:24,094: Image not found for item SJ-SRB-22F72
# 2022-09-14 23:39:24,096: Image not found for item SJ-SRB-22F73
# 2022-09-14 23:39:24,098: Image not found for item SJ-SRB-22F74
# 2022-09-14 23:39:24,099: Image not found for item SJ-SRB-22F75
# 2022-09-14 23:39:24,100: Image not found for item SJ-SRB-22F76
# 2022-09-14 23:39:24,103: Image not found for item SJ-SRB-22F77
# 2022-09-14 23:39:24,104: Image not found for item SJ-SRB-22F78
# 2022-09-14 23:39:24,105: Image not found for item SJ-SRB-22F79
# 2022-09-14 23:39:24,106: Image not found for item SJ-SRB-22F80
# 2022-09-14 23:39:24,108: Image not found for item SJ-SRB-22F81
# 2022-09-14 23:39:24,109: Image not found for item SJ-SRB-22G32
# 2022-09-14 23:39:24,111: Image not found for item SJ-SRB-22G33
# 2022-09-14 23:39:24,113: Image not found for item SJ-SRB-22G38
# 2022-09-14 23:39:24,115: Image not found for item SJ-SRB-22G62
# 2022-09-14 23:39:24,116: Image not found for item SJ-SRB-2412
# 2022-09-14 23:39:24,117: Image not found for item SJ-SRB-3059
# 2022-09-14 23:39:24,118: Image not found for item SJ-SRB-3310
# 2022-09-14 23:39:24,120: Image not found for item SJ-SRB-345
# 2022-09-14 23:39:24,121: Image not found for item SJ-SRB-364
# 2022-09-14 23:39:24,122: Image not found for item SJ-SRB-3829
# 2022-09-14 23:39:24,125: Image not found for item SJ-SRB-4067
# 2022-09-14 23:39:24,126: Image not found for item SJ-SRB-6052
# 2022-09-14 23:39:24,128: Image not found for item SJ-SRB-6102
# 2022-09-14 23:39:24,129: Image not found for item SJ-SRB-6129
# 2022-09-14 23:39:24,130: Image not found for item SJ-SRB-6149
# 2022-09-14 23:39:24,131: Image not found for item SJ-SRB-6150
# 2022-09-14 23:39:24,133: Image not found for item SJ-SRB-6151
# 2022-09-14 23:39:24,134: Image not found for item SJ-SRB-6152
# 2022-09-14 23:39:24,135: Image not found for item SJ-SRB-6153
# 2022-09-14 23:39:24,136: Image not found for item SJ-SRB-6228
# 2022-09-14 23:39:24,138: Image not found for item SJ-SRB-6501
# 2022-09-14 23:39:24,139: Image not found for item SJ-SRB-6502
# 2022-09-14 23:39:24,141: Image not found for item SJ-SRB-6814
# 2022-09-14 23:39:24,142: Image not found for item SJ-SRB-6816
# 2022-09-14 23:39:24,144: Image not found for item SJ-SRB-6817
# 2022-09-14 23:39:24,145: Image not found for item SJ-SRB-6821
# 2022-09-14 23:39:24,147: Image not found for item SJ-SRB-6861
# 2022-09-14 23:39:24,148: Image not found for item SJ-SRB-6864
# 2022-09-14 23:39:24,149: Image not found for item SJ-SRB-6866
# 2022-09-14 23:39:24,150: Image not found for item SJ-SRB-6868
# 2022-09-14 23:39:24,152: Image not found for item SJ-SRB-6929
# 2022-09-14 23:39:24,155: Image not found for item SJ-SRB-6930 N
# 2022-09-14 23:39:24,156: Image not found for item SJ-SRB-6931 N
# 2022-09-14 23:39:24,157: Image not found for item SJ-SRB-6949
# 2022-09-14 23:39:24,159: Image not found for item SJ-SRB-6964
# 2022-09-14 23:39:24,160: Image not found for item SJ-SRB-7000
# 2022-09-14 23:39:24,161: Image not found for item SJ-SRB-7006
# 2022-09-14 23:39:24,162: Image not found for item SJ-SRB-7034
# 2022-09-14 23:39:24,163: Image not found for item SJ-SRB-7035
# 2022-09-14 23:39:24,164: Image not found for item SJ-SRB-704
# 2022-09-14 23:39:24,165: Image not found for item SJ-SRB-7061
# 2022-09-14 23:39:24,166: Image not found for item SJ-SRB-7062
# 2022-09-14 23:39:24,168: Image not found for item SJ-SRB-8531
# 2022-09-14 23:39:24,169: Image not found for item SJ-SRB-9024
# 2022-09-14 23:39:24,170: Image not found for item SJ-SRB-9145
# 2022-09-14 23:39:24,171: Image not found for item SJ-SRB-9191
# 2022-09-14 23:39:24,174: Image not found for item SJ-SRB-9191B
# 2022-09-14 23:39:24,175: Image not found for item SJ-SRB-9192
# 2022-09-14 23:39:24,176: Image not found for item SJ-SRB-9302
# 2022-09-14 23:39:24,178: Image not found for item SJ-STT-21K14
# 2022-09-14 23:39:24,179: Image not found for item SJ-STT-21K18
# 2022-09-14 23:39:24,182: Image not found for item SJ-STT-22F06
# 2022-09-14 23:39:24,183: Image not found for item SJ-STT-22F07
# 2022-09-14 23:39:24,185: Image not found for item SJ-STT-22F40
# 2022-09-14 23:39:24,187: Image not found for item SJ-STT-22F53
# 2022-09-14 23:39:24,188: Image not found for item SJ-STT-22G52
# 2022-09-14 23:39:24,189: Image not found for item SJ-STT-22G60
# 2022-09-14 23:39:24,191: Image not found for item SJ-STT-344
# 2022-09-14 23:39:24,192: Image not found for item SJ-STT-3736
# 2022-09-14 23:39:24,195: Image not found for item SJ-STT-3738
# 2022-09-14 23:39:24,196: Image not found for item SJ-STT-3752
# 2022-09-14 23:39:24,197: Image not found for item SJ-STT-3802
# 2022-09-14 23:39:24,199: Image not found for item SJ-STT-434
# 2022-09-14 23:39:24,200: Image not found for item SJ-STT-542
# 2022-09-14 23:39:24,201: Image not found for item SJ-STT-543
# 2022-09-14 23:39:24,202: Image not found for item SJ-STT-589
# 2022-09-14 23:39:24,203: Image not found for item SJ-STT-591
# 2022-09-14 23:39:24,204: Image not found for item SJ-STT-9067
# 2022-09-14 23:39:24,205: Image not found for item SJ-STT-9177
# 2022-09-14 23:39:24,207: Image not found for item SJ-STT-9306
# 2022-09-14 23:39:24,208: Image not found for item SJ-STT-9307
# 2022-09-14 23:39:24,210: Image not found for item SJ-STT-9501
# 2022-09-14 23:39:24,211: Image not found for item SJ-STT-9505
# 2022-09-14 23:39:24,212: Image not found for item SJ-STT-9506
# 2022-09-14 23:39:24,213: Image not found for item SJ-HBN-30102C
# 2022-09-14 23:39:24,215: Image not found for item SJ-HBN-30103B
# 2022-09-14 23:39:24,217: Image not found for item SJ-HBN-30105B
# 2022-09-14 23:39:24,218: Image not found for item SJ-HBN-301A
# 2022-09-14 23:39:24,220: Image not found for item SJ-HBN-301MB
# 2022-09-14 23:39:24,221: Image not found for item SJ-HBN-301SB
# 2022-09-14 23:39:24,223: Image not found for item SJ-HBN-30702C
# 2022-09-14 23:39:24,224: Image not found for item SJ-HBN-30703B
# 2022-09-14 23:39:24,226: Image not found for item SJ-HBN-30705B
# 2022-09-14 23:39:24,227: Image not found for item SJ-HBN-307MB
# 2022-09-14 23:39:24,228: Image not found for item SJ-HBN-307SB
# 2022-09-14 23:39:24,229: Image not found for item SJ-HBN-32502C
# 2022-09-14 23:39:24,232: Image not found for item SJ-HBN-32503B
# 2022-09-14 23:39:24,233: Image not found for item SJ-HBN-32503G
# 2022-09-14 23:39:24,234: Image not found for item SJ-HBN-32505B
# 2022-09-14 23:39:24,235: Image not found for item SJ-HBN-35002C
# 2022-09-14 23:39:24,237: Image not found for item SJ-HBN-35003B
# 2022-09-14 23:39:24,238: Image not found for item SJ-HBN-35003G
# 2022-09-14 23:39:24,239: Image not found for item SJ-HBN-35005B
# 2022-09-14 23:39:24,240: Image not found for item SJ-HBN-350MB
# 2022-09-14 23:39:24,242: Image not found for item SJ-HBN-350SB
# 2022-09-14 23:39:24,243: Image not found for item SJ-HBN-35102C
# 2022-09-14 23:39:24,244: Image not found for item SJ-HBN-35103B
# 2022-09-14 23:39:24,245: Image not found for item SJ-HBN-35103G
# 2022-09-14 23:39:24,247: Image not found for item SJ-HBN-35105B
# 2022-09-14 23:39:24,248: Image not found for item SJ-HBN-351A
# 2022-09-14 23:39:24,251: Image not found for item SJ-HBN-351MB
# 2022-09-14 23:39:24,253: Image not found for item SJ-HBN-351SB
# 2022-09-14 23:39:24,254: Image not found for item SJ-HBN-35202C
# 2022-09-14 23:39:24,255: Image not found for item SJ-HBN-35203B
# 2022-09-14 23:39:24,257: Image not found for item SJ-HBN-35203G
# 2022-09-14 23:39:24,258: Image not found for item SJ-HBN-35205B
# 2022-09-14 23:39:24,259: Image not found for item SJ-HBN-352A
# 2022-09-14 23:39:24,260: Image not found for item SJ-HBN-352MB
# 2022-09-14 23:39:24,262: Image not found for item SJ-HBN-352SB
# 2022-09-14 23:39:24,263: Image not found for item SJ-HBN-35902C
# 2022-09-14 23:39:24,266: Image not found for item SJ-HBN-35903B
# 2022-09-14 23:39:24,267: Image not found for item SJ-HBN-35903G
# 2022-09-14 23:39:24,268: Image not found for item SJ-HBN-35905B
# 2022-09-14 23:39:24,271: Image not found for item SJ-HBN-359MB
# 2022-09-14 23:39:24,272: Image not found for item SJ-HBN-359SB
# 2022-09-14 23:39:24,274: Image not found for item SJ-HBN-37502C
# 2022-09-14 23:39:24,275: Image not found for item SJ-HBN-37503B
# 2022-09-14 23:39:24,277: Image not found for item SJ-HBN-37505B
# 2022-09-14 23:39:24,279: Image not found for item SJ-HBN-375MB
# 2022-09-14 23:39:24,280: Image not found for item SJ-HBN-375SB
# 2022-09-14 23:39:24,282: Image not found for item SJ-HCH-131902C
# 2022-09-14 23:39:24,283: Image not found for item SJ-HCH-131905B
# 2022-09-14 23:39:24,285: Image not found for item SJ-HCH-132003B
# 2022-09-14 23:39:24,286: Image not found for item SJ-HCH-132005B
# 2022-09-14 23:39:24,288: Image not found for item SJ-HCH-132902C
# 2022-09-14 23:39:24,289: Image not found for item SJ-HCH-132903B
# 2022-09-14 23:39:24,291: Image not found for item SJ-HCH-132905B
# 2022-09-14 23:39:24,292: Image not found for item SJ-HCH-1329MB
# 2022-09-14 23:39:24,293: Image not found for item SJ-HCH-1329SB
# 2022-09-14 23:39:24,296: Image not found for item SJ-HCH-134902C
# 2022-09-14 23:39:24,298: Image not found for item SJ-HCH-134905B
# 2022-09-14 23:39:24,299: Image not found for item SJ-HCH-135002C
# 2022-09-14 23:39:24,301: Image not found for item SJ-HCH-135003B
# 2022-09-14 23:39:24,302: Image not found for item SJ-HCH-135005B
# 2022-09-14 23:39:24,304: Image not found for item SJ-HCH-135802C
# 2022-09-14 23:39:24,305: Image not found for item SJ-HCH-135803B
# 2022-09-14 23:39:24,307: Image not found for item SJ-HCH-135805B
# 2022-09-14 23:39:24,308: Image not found for item SJ-HCH-137602C
# 2022-09-14 23:39:24,309: Image not found for item SJ-HCH-137603B
# 2022-09-14 23:39:24,312: Image not found for item SJ-HCH-137605B
# 2022-09-14 23:39:24,314: Image not found for item SJ-HCH-137702C
# 2022-09-14 23:39:24,316: Image not found for item SJ-HCH-137703B
# 2022-09-14 23:39:24,317: Image not found for item SJ-HCH-137705B
# 2022-09-14 23:39:24,319: Image not found for item SJ-HCH-131903G
# 2022-09-14 23:39:24,320: Image not found for item SJ-HCH-132003G
# 2022-09-14 23:39:24,321: Image not found for item SJ-HCH-132903G
# 2022-09-14 23:39:24,324: Image not found for item SJ-HCH-134903G
# 2022-09-14 23:39:24,325: Image not found for item SJ-HCH-135003G
# 2022-09-14 23:39:24,327: Image not found for item SJ-HCH-135803G
# 2022-09-14 23:39:24,329: Image not found for item SJ-HCH-137603G
# 2022-09-14 23:39:24,330: Image not found for item SJ-HCH-137703G
# 2022-09-14 23:39:24,332: Image not found for item SJ-HCH-130702C
# 2022-09-14 23:39:24,333: Image not found for item SJ-HCH-130703B
# 2022-09-14 23:39:24,335: Image not found for item SJ-HCH-130705B
# 2022-09-14 23:39:24,336: Image not found for item SJ-HCH-131202C
# 2022-09-14 23:39:24,338: Image not found for item SJ-HCH-131203B
# 2022-09-14 23:39:24,339: Image not found for item SJ-HCH-131205B
# 2022-09-14 23:39:24,341: Image not found for item SJ-HCH-132203B
# 2022-09-14 23:39:24,343: Image not found for item SJ-HCH-132205B
# 2022-09-14 23:39:24,344: Image not found for item SJ-HCH-132802C
# 2022-09-14 23:39:24,345: Image not found for item SJ-HCH-132803B
# 2022-09-14 23:39:24,346: Image not found for item SJ-HCH-132805B
# 2022-09-14 23:39:24,347: Image not found for item SJ-HCH-1328MB
# 2022-09-14 23:39:24,349: Image not found for item SJ-HCH-1328SB
# 2022-09-14 23:39:24,351: Image not found for item SJ-HCH-139702C
# 2022-09-14 23:39:24,351: Image not found for item SJ-HCH-139703B
# 2022-09-14 23:39:24,353: Image not found for item SJ-HCH-139705B
# 2022-09-14 23:39:24,354: Image not found for item SJ-HCH-1397MB
# 2022-09-14 23:39:24,356: Image not found for item SJ-HCH-1397SB
# 2022-09-14 23:39:24,357: Image not found for item SJ-HCH-139803B
# 2022-09-14 23:39:24,359: Image not found for item SJ-HCH-139805B
# 2022-09-14 23:39:24,360: Image not found for item SJ-HCH-1398MB
# 2022-09-14 23:39:24,362: Image not found for item SJ-HCH-1398SB
# 2022-09-14 23:39:24,363: Image not found for item SJ-HCH-141502C
# 2022-09-14 23:39:24,365: Image not found for item SJ-HCH-141505B
# 2022-09-14 23:39:24,366: Image not found for item SJ-HCH-1415MB
# 2022-09-14 23:39:24,368: Image not found for item SJ-HCH-1415SB
# 2022-09-14 23:39:24,369: Image not found for item SJ-HCH-130703G
# 2022-09-14 23:39:24,371: Image not found for item SJ-HCH-131203G
# 2022-09-14 23:39:24,373: Image not found for item SJ-HCH-132203G
# 2022-09-14 23:39:24,374: Image not found for item SJ-HCH-132803G
# 2022-09-14 23:39:24,376: Image not found for item SJ-HCH-139703G
# 2022-09-14 23:39:24,377: Image not found for item SJ-HCH-139803G
# 2022-09-14 23:39:24,380: Image not found for item SJ-HCH-141503G
# 2022-09-14 23:39:24,382: Image not found for item SJ-HCH-131502C
# 2022-09-14 23:39:24,383: Image not found for item SJ-HCH-131503B
# 2022-09-14 23:39:24,386: Image not found for item SJ-HCH-131505B
# 2022-09-14 23:39:24,388: Image not found for item SJ-HCH-132102C
# 2022-09-14 23:39:24,390: Image not found for item SJ-HCH-132103B
# 2022-09-14 23:39:24,391: Image not found for item SJ-HCH-132105B
# 2022-09-14 23:39:24,393: Image not found for item SJ-HCH-134502C
# 2022-09-14 23:39:24,395: Image not found for item SJ-HCH-134503B
# 2022-09-14 23:39:24,397: Image not found for item SJ-HCH-134505B
# 2022-09-14 23:39:24,398: Image not found for item SJ-HCH-134602C
# 2022-09-14 23:39:24,400: Image not found for item SJ-HCH-134603B
# 2022-09-14 23:39:24,402: Image not found for item SJ-HCH-134605B
# 2022-09-14 23:39:24,403: Image not found for item SJ-HCH-140102C
# 2022-09-14 23:39:24,405: Image not found for item SJ-HCH-140103B
# 2022-09-14 23:39:24,408: Image not found for item SJ-HCH-140105B
# 2022-09-14 23:39:24,409: Image not found for item SJ-HCH-131503G
# 2022-09-14 23:39:24,411: Image not found for item SJ-HCH-132103G
# 2022-09-14 23:39:24,412: Image not found for item SJ-HCH-134503G
# 2022-09-14 23:39:24,413: Image not found for item SJ-HCH-134603G
# 2022-09-14 23:39:24,414: Image not found for item SJ-HCH-140103G
# 2022-09-14 23:39:24,416: Image not found for item SJ-HCH-135602C
# 2022-09-14 23:39:24,417: Image not found for item SJ-HCH-135603B
# 2022-09-14 23:39:24,419: Image not found for item SJ-HCH-135605B
# 2022-09-14 23:39:24,420: Image not found for item SJ-HCH-1356MB
# 2022-09-14 23:39:24,422: Image not found for item SJ-HCH-1356SB
# 2022-09-14 23:39:24,423: Image not found for item SJ-HCH-135603G
# 2022-09-14 23:39:24,424: Image not found for item SJ-HCH-1356A
# 2022-09-14 23:39:24,425: Image not found for item SJ-HHB-52503B
# 2022-09-14 23:39:24,428: Image not found for item SJ-HHB-525A
# 2022-09-14 23:39:24,429: Image not found for item SJ-HHB-525MB
# 2022-09-14 23:39:24,430: Image not found for item SJ-HHB-525SB
# 2022-09-14 23:39:24,431: Image not found for item SJ-HHB-58102C
# 2022-09-14 23:39:24,433: Image not found for item SJ-HHB-58103B
# 2022-09-14 23:39:24,435: Image not found for item SJ-HHB-58105B
# 2022-09-14 23:39:24,436: Image not found for item SJ-HHB-581SB
# 2022-09-14 23:39:24,437: Image not found for item SJ-HHB-58302C
# 2022-09-14 23:39:24,439: Image not found for item SJ-HHB-58303B
# 2022-09-14 23:39:24,441: Image not found for item SJ-HHB-58305B
# 2022-09-14 23:39:24,442: Image not found for item SJ-HHB-583MB
# 2022-09-14 23:39:24,444: Image not found for item SJ-HHB-58503B
# 2022-09-14 23:39:24,445: Image not found for item SJ-HHB-585MB
# 2022-09-14 23:39:24,447: Image not found for item SJ-HHB-585SB
# 2022-09-14 23:39:24,448: Image not found for item SJ-SRP-6825
# 2022-09-14 23:39:24,449: Image not found for item SJ-SRP-9055
# 2022-09-14 23:39:24,451: Image not found for item SJ-SRP-9056
# 2022-09-14 23:39:24,453: Image not found for item SJ-SRP-9057
# 2022-09-14 23:39:24,454: Image not found for item SJ-SRP-9058
# 2022-09-14 23:39:24,455: Image not found for item SJ-SRP-9059
# 2022-09-14 23:39:24,457: Image not found for item SJ-HATX-190Z
# 2022-09-14 23:39:24,458: Image not found for item SJ-HATX-238Z
# 2022-09-14 23:39:24,459: Image not found for item SJ-HAYZ-3007Z
# 2022-09-14 23:39:24,461: Image not found for item SJ-TX-7982Z
# 2022-09-14 23:39:24,462: Image not found for item SJ-TX-8035Z
# 2022-09-14 23:39:24,463: Image not found for item SJ-TX-8293Z
# 2022-09-14 23:39:24,466: Image not found for item SJ-TX-8326Z
# 2022-09-14 23:39:24,467: Image not found for item SJ-TX-8360Z
# 2022-09-14 23:39:24,468: Image not found for item SJ-TXTD-6731Z
# 2022-09-14 23:39:24,470: Image not found for item SJ-TXTD-6778Z
# 2022-09-14 23:39:24,472: Image not found for item SJ-TXTD-6906Z
# 2022-09-14 23:39:24,473: Image not found for item SJ-TXTD-6922Z
# 2022-09-14 23:39:24,475: Image not found for item SJ-TXTD-6954Z
# 2022-09-14 23:39:24,476: Image not found for item SJ-TXYJ-798Z
# 2022-09-14 23:39:24,477: Image not found for item SJ-TXYJ-812Z
# 2022-09-14 23:39:24,479: Image not found for item SJ-TXYJ-843Z
# 2022-09-14 23:39:24,481: Image not found for item SJ-TXYJ-844Z
# 2022-09-14 23:39:24,482: Image not found for item SJ-TXYJ-845Z
# 2022-09-14 23:39:24,484: Image not found for item SJ-TXYJ-847Z
# 2022-09-14 23:39:24,485: Image not found for item SJ-TXYJ-849Z
# 2022-09-14 23:39:24,487: Image not found for item SJ-TXYJ-850Z
# 2022-09-14 23:39:24,488: Image not found for item SJ-TXYJ-851Z
# 2022-09-14 23:39:24,489: Image not found for item SJ-TXYJ-852Z
# 2022-09-14 23:39:24,491: Image not found for item SJ-SBR-1044
# 2022-09-14 23:39:24,492: Image not found for item SJ-SBR-22F39
# 2022-09-14 23:39:24,493: Image not found for item SJ-SBR-3150
# 2022-09-14 23:39:24,495: Image not found for item SJ-SBR-351
# 2022-09-14 23:39:24,496: Image not found for item SJ-SBR-3596
# 2022-09-14 23:39:24,498: Image not found for item SJ-SBR-3786
# 2022-09-14 23:39:24,499: Image not found for item SJ-SBR-4180
# 2022-09-14 23:39:24,501: Image not found for item SJ-SBR-604
# 2022-09-14 23:39:24,503: Image not found for item SJ-SBR-6195
# 2022-09-14 23:39:24,504: Image not found for item SJ-SBR-9019
# 2022-09-14 23:39:24,505: Image not found for item SJ-SBR-9071
# 2022-09-14 23:39:24,507: Image not found for item SJ-SBR-9074
# 2022-09-14 23:39:24,508: Image not found for item SJ-SBR-9075
# 2022-09-14 23:39:24,510: Image not found for item SJ-SBR-9076
# 2022-09-14 23:39:24,511: Image not found for item SJ-SBR-9077
# 2022-09-14 23:39:24,513: Image not found for item SJ-SBR-9105
# 2022-09-14 23:39:24,514: Image not found for item SJ-SBR-9118
# 2022-09-14 23:39:24,515: Image not found for item SJ-SBR-9121
# 2022-09-14 23:39:24,517: Image not found for item SJ-SBR-9130
# 2022-09-14 23:39:24,518: Image not found for item SJ-SER-606
# 2022-09-14 23:39:24,519: Image not found for item SJ-SER-607
# 2022-09-14 23:39:24,521: Image not found for item SJ-SER-612
# 2022-09-14 23:39:24,522: Image not found for item SJ-SER-614
# 2022-09-14 23:39:24,523: Image not found for item SJ-SER-615
# 2022-09-14 23:39:24,524: Image not found for item SJ-SER-616
# 2022-09-14 23:39:24,526: Image not found for item SJ-SER-617
# 2022-09-14 23:39:24,527: Image not found for item SJ-SER-620
# 2022-09-14 23:39:24,530: Image not found for item SJ-SER-626
# 2022-09-14 23:39:24,531: Image not found for item SJ-SER-628
# 2022-09-14 23:39:24,533: Image not found for item SJ-SER-9005
# 2022-09-14 23:39:24,534: Image not found for item SJ-SER-9008
# 2022-09-14 23:39:24,535: Image not found for item SJ-SFR-2001
# 2022-09-14 23:39:24,537: Image not found for item SJ-SFR-3163
# 2022-09-14 23:39:24,538: Image not found for item SJ-SML-3087
# 2022-09-14 23:39:24,539: Image not found for item SJ-SNK-22F35
# 2022-09-14 23:39:24,540: Image not found for item SJ-SNK-22F36
# 2022-09-14 23:39:24,543: Image not found for item SJ-SNK-22F37
# 2022-09-14 23:39:24,546: Image not found for item SJ-SNK-22F38
# 2022-09-14 23:39:24,548: Image not found for item SJ-SNK-6818
# 2022-09-14 23:39:24,549: Image not found for item SJ-SNK-766
# 2022-09-14 23:39:24,550: Image not found for item SJ-SNK-8507
# 2022-09-14 23:39:24,552: Image not found for item SJ-SNK-9126
# 2022-09-14 23:39:24,553: Image not found for item SJ-SNK-9128
# 2022-09-14 23:39:24,554: Image not found for item SJ-SRP-337
# 2022-09-14 23:39:24,556: Image not found for item SJ-SRP-562
# 2022-09-14 23:39:24,557: Image not found for item SJ-STP-1200
# 2022-09-14 23:39:24,559: Image not found for item SJ-STP-1201
# 2022-09-14 23:39:24,562: Image not found for item SJ-STP-3677
# 2022-09-14 23:39:24,564: Image not found for item SJ-STP-593
# 2022-09-14 23:39:24,565: Image not found for item KJ-18
# 2022-09-14 23:39:24,566: Image not found for item SJ-204-11
# 2022-09-14 23:39:24,568: Image not found for item PN-11
# 2022-09-14 23:39:24,570: Image not found for item PN-12
# 2022-09-14 23:39:24,571: Image not found for item PN-6
# 2022-09-14 23:39:24,573: Image not found for item LOOM BANDS
# 2022-09-14 23:39:24,574: Image not found for item SJ-2A-1051
# 2022-09-14 23:39:24,576: Image not found for item SJ-PN-1059
# 2022-09-14 23:39:24,577: Image not found for item SJ-PN-2045
# 2022-09-14 23:39:24,579: Image not found for item SJ-PN-503
# 2022-09-14 23:39:24,581: Image not found for item SJ-PN-512
# 2022-09-14 23:39:24,583: Image not found for item SJ-PN-539
# 2022-09-14 23:39:24,585: Image not found for item SJ-PN-585
# 2022-09-14 23:39:24,586: Image not found for item SJ-PN-588
# 2022-09-14 23:39:24,588: Image not found for item SJ-PN-593
# 2022-09-14 23:39:24,589: Image not found for item SJ-PN-7001
# 2022-09-14 23:39:24,590: Image not found for item SJ-PN-7009
# 2022-09-14 23:39:24,591: Image not found for item RAW TIK TIK

# %%
def create_captioned_img(df, primary_key, labels, cat=None):
    
    global settings
    
    pipeline = list()
    total_height = 0
    
    raw_image = Image.open(df.at[primary_key, 'ip_file_path'])
    
    # Resizing image
    w,h = raw_image.size

    IMG_WIDTH = w
    new_height = h
    
    # new_height = int((h/w)*IMG_WIDTH)

#     logging.debug(f"Resizing image to {IMG_WIDTH}px x {new_height}px.")
#     raw_image = raw_image.resize((IMG_WIDTH, new_height))
    pipeline.append(raw_image)
    total_height += new_height
    
    font_size = int((w/2100)*settings['labelling_schema']['font_size'])
    FONT_SETTINGS = ImageFont.truetype(settings['labelling_schema']['font_file'], font_size)
    LINE_HEIGHT = int((w/2100)*settings['labelling_schema']['line_height']) # pixels
    LABELS_PER_LINE = settings['labelling_schema']['labels_per_line']
    
    
    # Blank line above
    im = Image.new(mode="RGB",size=(IMG_WIDTH, int(LINE_HEIGHT/2)), color=(250, 250, 250))
    pipeline.append(im)
    total_height += int(LINE_HEIGHT/2)
    
    # Preparing text to write
    txt_lines = [[]]
    for i in range(len(labels)):
        
        if len(txt_lines[-1])==LABELS_PER_LINE:
            txt_lines.append(list())
        
        if labels[i]==df.index.name:
            msg = labels[i]+": "+primary_key
        elif labels[i]=="Rate/Unit":
            rate_per_unit = f"{df.at[primary_key, cat]:.2f}/"+str(df.at[primary_key, 'Base Unit']) 
            msg = "Rate: ₹ "+rate_per_unit
        elif labels[i]=="Min Qty/Ord":
            msg = f"Min Ord: {df.at[primary_key, 'Min Qty']} {df.at[primary_key, 'Ord Unit']}" 
        else:
            msg = labels[i]+": "+str(df.at[primary_key, labels[i]])
        
        txt_lines[-1].append(msg)
    
    # Writing text to image line-by-line
    for lines in txt_lines:
        im = Image.new(mode="RGB",size=(IMG_WIDTH, LINE_HEIGHT), color=(250, 250, 250))
        draw = ImageDraw.Draw(im)
        msg = "        ".join(lines)
        draw.text((IMG_WIDTH/2, LINE_HEIGHT/2), msg, fill='black', font=FONT_SETTINGS, anchor='mm')
        pipeline.append(im)
        total_height += LINE_HEIGHT
    
    # Blank line below
    im = Image.new(mode="RGB",size=(IMG_WIDTH, int(LINE_HEIGHT/2)), color=(250, 250, 250))
    pipeline.append(im)
    total_height += int(LINE_HEIGHT/2)
    
    # Final Image
    final_img = Image.new(mode='RGB', size=(IMG_WIDTH, total_height))
    
    height_counter = 0
    for i in range(len(pipeline)):
        final_img.paste(pipeline[i], box=(0, height_counter))
        _, h = pipeline[i].size
        height_counter += h
    
    return final_img

# %%
OUTPUT_FOLDER = settings["img_output_folder"]

for i in tqdm(list(item_catalog[item_catalog['ip_file_path']!=''].index), desc='Creating images: ', unit='item'):
    if item_catalog.at[i, 'ip_file_path']!='':
        for variation in settings['labelling_schema']['label_variations']:

            img = create_captioned_img(item_catalog, i, variation['label_cols'], cat=variation['price_col'])
            
            if item_catalog.at[i, settings['labelling_schema']["to_clear_col_name"]] in ["Y", "y"]:
                heading = settings['labelling_schema']["to_clear_col_name"]
            else:
                heading = item_catalog.at[i, 'last_purchase']
            
            output_path = OUTPUT_FOLDER + r'/' + variation['price_col'] + r'/' + heading + r'/' + item_catalog.at[i, 'Group'] + r'/' + item_catalog.at[i, 'Category'] + r'/'
            
            if not os.path.isdir(output_path):
                os.makedirs(output_path)
            
            img.save(output_path+i+".jpg", format='JPEG')
# Out:
# Creating images: 100%|█████████████████████████████████████████████████████████████| 204/204 [00:56<00:00,  3.64item/s]
